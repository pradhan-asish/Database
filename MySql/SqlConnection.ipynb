# %%
import mySqlConnection as mysql
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# <ipython-input-1-a643b5ec9577> in <module>
# ----> 1 import mySqlConnection as mysql
#
# ~\Desktop\GitHub\Python\Database\MySql\mySqlConnection.py in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(
#       3   host="127.0.0.1",
#       4   user="asish",
#       5   password="Pradhan@1994",
#
# ~\anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# ~\anaconda3\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     714
#     715         self.disconnect()
# --> 716         self._open_connection()
#     717         self._post_connection()
#     718
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     206         self._socket.open_connection()
#     207         self._do_handshake()
# --> 208         self._do_auth(self._user, self._password,
#     209                       self._database, self._client_flags, self._charset_id,
#     210                       self._ssl)
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     142             auth_plugin=self._auth_plugin)
#     143         self._socket.send(packet)
# --> 144         self._auth_switch_request(username, password)
#     145
#     146         if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _auth_switch_request(self, username, password)
#     165             (new_auth_plugin,
#     166              auth_data) = self._protocol.parse_auth_switch_request(packet)
# --> 167             auth = get_auth_plugin(new_auth_plugin)(
#     168                 auth_data, password=password, ssl_enabled=self._ssl_active)
#     169             response = auth.auth_response()
#
# ~\anaconda3\lib\site-packages\mysql\connector\authentication.py in get_auth_plugin(plugin_name)
#     188             return authclass
#     189
# --> 190     raise errors.NotSupportedError(
#     191         "Authentication plugin '{0}' is not supported".format(plugin_name))
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported

# %%
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# <ipython-input-27-a0a2e52db165> in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(
#       3   host="localhost",
#       4   user="yourusername",
#       5   password="yourpassword"
#
# ~\anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# --> 179         return MySQLConnection(*args, **kwargs)
#     180 Connect = connect  # pylint: disable=C0103
#     181
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#      93
#      94         if len(kwargs) > 0:
# ---> 95             self.connect(**kwargs)
#      96
#      97     def _do_handshake(self):
#
# ~\anaconda3\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     714
#     715         self.disconnect()
# --> 716         self._open_connection()
#     717         self._post_connection()
#     718
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     206         self._socket.open_connection()
#     207         self._do_handshake()
# --> 208         self._do_auth(self._user, self._password,
#     209                       self._database, self._client_flags, self._charset_id,
#     210                       self._ssl)
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     135             self._ssl_active = True
#     136
# --> 137         packet = self._protocol.make_auth(
#     138             handshake=self._handshake,
#     139             username=username, password=password, database=database,
#
# ~\anaconda3\lib\site-packages\mysql\connector\protocol.py in make_auth(self, handshake, username, password, database, charset, client_flags, max_allowed_packet, ssl_enabled, auth_plugin)
#      97                              username_bytes)
#      98
# ---> 99         packet += self._auth_response(client_flags, username, password,
#     100                                       database,
#     101                                       auth_plugin,
#
# ~\anaconda3\lib\site-packages\mysql\connector\protocol.py in _auth_response(self, client_flags, username, password, database, auth_plugin, auth_data, ssl_enabled)
#      56
#      57         try:
# ---> 58             auth = get_auth_plugin(auth_plugin)(
#      59                 auth_data,
#      60                 username=username, password=password, database=database,
#
# ~\anaconda3\lib\site-packages\mysql\connector\authentication.py in get_auth_plugin(plugin_name)
#     188             return authclass
#     189
# --> 190     raise errors.NotSupportedError(
#     191         "Authentication plugin '{0}' is not supported".format(plugin_name))
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported

# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
  user="asish",
  password="Pradhan@1994",
  database='p_table',
  auth_plugin='mysql_native_password')
# Out:
# ---------------------------------------------------------------------------
# NotSupportedError                         Traceback (most recent call last)
# <ipython-input-5-7ebbc5cc0662> in <module>
#       1 import mysql.connector
# ----> 2 mydb = mysql.connector.connect(
#       3   host="localhost",
#       4   user="asish",
#       5   password="Pradhan@1994",
#
# ~\anaconda3\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     177             new_config = config.copy()
#     178             new_config.update(server)
# --> 179             new_config.pop('priority', None)
#     180             try:
#     181                 return connect(**new_config)
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#      93
#      94         self._use_unicode = True
# ---> 95         self._get_warnings = False
#      96         self._raise_on_warnings = False
#      97         self._buffered = False
#
# ~\anaconda3\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     714
#     715         Returns self.client_flags
# --> 716         """
#     717         if isinstance(flags, int) and flags > 0:
#     718             self._client_flags = flags
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     206                                        ssl_options.get('verify_identity') or
#     207                                        False,
# --> 208                                        tls_ciphersuites,
#     209                                        ssl_options.get('tls_versions'))
#     210             self._ssl_active = True
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     142         self._conn_attrs.update((default_conn_attrs))
#     143
# --> 144     def _do_handshake(self):
#     145         """Get the handshake from the MySQL server"""
#     146         packet = self._socket.recv()
#
# ~\anaconda3\lib\site-packages\mysql\connector\connection.py in _auth_switch_request(self, username, password)
#     165                 raise errors.InterfaceError(err_msg)
#     166             if self._ssl.get('verify_cert'):
# --> 167                 raise errors.InterfaceError("SSL is required but the server "
#     168                                             "doesn't support it", errno=2026)
#     169             self._client_flags &= ~ClientFlag.SSL
#
# ~\anaconda3\lib\site-packages\mysql\connector\authentication.py in get_auth_plugin(plugin_name)
#     188
#     189         return password + b'\x00'
# --> 190
#     191
#     192 class MySQLCachingSHA2PasswordAuthPlugin(BaseAuthPlugin):
#
# NotSupportedError: Authentication plugin 'caching_sha2_password' is not supported
