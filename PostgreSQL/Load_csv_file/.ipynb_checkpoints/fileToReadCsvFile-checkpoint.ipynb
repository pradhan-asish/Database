# %%
import pandas as pd

# %%
df = pd.read_csv('Emp_Details.csv')

# %%
df
# Out:
#    emp_id  emp_name  emp_age  \
# 0     121     Asish       26
# 1     131    Deepak       28
# 2     141    Shakul       29
# 3     151       Anu       25
# 4     161  Abhishek       26
# 5     171     Varun       28
# 6     181    Suhani       26
# 7     191     Divya       28
# 8     101    Satish       27
# 9     111        Sk       29
#
#                                          emp_details
# 0  {\n"empSalary":"1000",\n"empRank":"1",\n"empDe...
# 1  {\n"empSalary":"2000",\n"empRank":"2",\n"empDe...
# 2  {\n"empSalary":"8000",\n"empRank":"3",\n"empDe...
# 3  {\n"empSalary":"7000",\n"empRank":"4",\n"empDe...
# 4  {\n"empSalary":"10000",\n"empRank":"5",\n"empD...
# 5  {\n"empSalary":"11000",\n"empRank":"6",\n"empD...
# 6  {\n"empSalary":"1000",\n"empRank":"7",\n"empDe...
# 7  {\n"empSalary":"80000",\n"empRank":"8",\n"empD...
# 8  {\n"empSalary":"10090",\n"empRank":"9",\n"empD...
# 9  {\n"empSalary":"77000",\n"empRank":"10",\n"emp...
