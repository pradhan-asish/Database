# %%
import pandas as pd
import json
import psycopg2
from psycopg2 import Error

# %%
df = pd.read_csv('Emp_Details.csv')

# %%
df
# Out:
#    emp_id  emp_name  emp_age  \
# 0     121     Asish       26
# 1     131    Deepak       28
# 2     141    Shakul       29
# 3     151       Anu       25
# 4     161  Abhishek       26
# 5     171     Varun       28
# 6     181    Suhani       26
# 7     191     Divya       28
# 8     101    Satish       27
# 9     111        Sk       29
#
#                                          emp_details
# 0  {"empSalary":"1000","empRank":"1","empDesignat...
# 1  {"empSalary":"2000","empRank":"2","empDesignat...
# 2  {"empSalary":"8000","empRank":"3","empDesignat...
# 3  {"empSalary":"7000","empRank":"4","empDesignat...
# 4  {"empSalary":"10000","empRank":"5","empDesigna...
# 5  {"empSalary":"11000","empRank":"6","empDesigna...
# 6  {"empSalary":"1000","empRank":"7","empDesignat...
# 7  {"empSalary":"80000","empRank":"8","empDesigna...
# 8  {"empSalary":"10090","empRank":"9","empDesigna...
# 9  {"empSalary":"77000","empRank":"10","empDesign...

# %%
df['emp_details']
# Out:
# 0    {"empSalary":"1000","empRank":"1","empDesignat...
# 1    {"empSalary":"2000","empRank":"2","empDesignat...
# 2    {"empSalary":"8000","empRank":"3","empDesignat...
# 3    {"empSalary":"7000","empRank":"4","empDesignat...
# 4    {"empSalary":"10000","empRank":"5","empDesigna...
# 5    {"empSalary":"11000","empRank":"6","empDesigna...
# 6    {"empSalary":"1000","empRank":"7","empDesignat...
# 7    {"empSalary":"80000","empRank":"8","empDesigna...
# 8    {"empSalary":"10090","empRank":"9","empDesigna...
# 9    {"empSalary":"77000","empRank":"10","empDesign...
# Name: emp_details, dtype: object

# %%
df['details']=df['emp_details'].apply(json.loads)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   emp_id       10 non-null     int64
#  1   emp_name     10 non-null     object
#  2   emp_age      10 non-null     int64
#  3   emp_details  10 non-null     object
#  4   details      10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
x= []
x = df['emp_details'].apply(json.loads)
x[1]
df1 = pd.DataFrame([df["emp_id"],df["emp_name"],df["emp_age"],df["details"]])
df1
# Out:
#                                                           0  \
# emp_id                                                  121
# emp_name                                              Asish
# emp_age                                                  26
# details   {'empSalary': '1000', 'empRank': '1', 'empDesi...
#
#                                                           1  \
# emp_id                                                  131
# emp_name                                             Deepak
# emp_age                                                  28
# details   {'empSalary': '2000', 'empRank': '2', 'empDesi...
#
#                                                           2  \
# emp_id                                                  141
# emp_name                                             Shakul
# emp_age                                                  29
# details   {'empSalary': '8000', 'empRank': '3', 'empDesi...
#
#                                                           3  \
# emp_id                                                  151
# emp_name                                                Anu
# emp_age                                                  25
# details   {'empSalary': '7000', 'empRank': '4', 'empDesi...
#
#                                                           4  \
# emp_id                                                  161
# emp_name                                           Abhishek
# emp_age                                                  26
# details   {'empSalary': '10000', 'empRank': '5', 'empDes...
#
#                                                           5  \
# emp_id                                                  171
# emp_name                                              Varun
# emp_age                                                  28
# details   {'empSalary': '11000', 'empRank': '6', 'empDes...
#
#                                                           6  \
# emp_id                                                  181
# emp_name                                             Suhani
# emp_age                                                  26
# details   {'empSalary': '1000', 'empRank': '7', 'empDesi...
#
#                                                           7  \
# emp_id                                                  191
# emp_name                                              Divya
# emp_age                                                  28
# details   {'empSalary': '80000', 'empRank': '8', 'empDes...
#
#                                                           8  \
# emp_id                                                  101
# emp_name                                             Satish
# emp_age                                                  27
# details   {'empSalary': '10090', 'empRank': '9', 'empDes...
#
#                                                           9
# emp_id                                                  111
# emp_name                                                 Sk
# emp_age                                                  29
# details   {'empSalary': '77000', 'empRank': '10', 'empDe...

# %%
try:
    # Connect to an existing database
    connection = psycopg2.connect(user="postgres",
                                  password="Pradhan@1994",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="mydb")
    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    sql = '''CREATE TABLE IF NOT EXISTS Employee (emp_id INT NOT NULL,
                emp_name Text NOT NULL,
                emp_age INT NOT NULL,
                emp_details JSON NULL,
                PRIMARY KEY (emp_id))'''
    cursor.execute(sql)
    print('Table created sucessully')
    connection.commit()
    connection.close()
    print("Table created")
    
except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
# Out:
# Table created sucessully
# Table created
# PostgreSQL connection is closed

# %%
try:
    # Connect to an existing database
    connection = psycopg2.connect(user="postgres",
                                  password="Pradhan@1994",
                                  host="127.0.0.1",
                                  port="5432",
                                  database="mydb")
    # Create a cursor to perform database operations
    cursor = connection.cursor()
    # Print PostgreSQL details
    sql = '''CREATE TABLE IF NOT EXISTS Employee (emp_id INT NOT NULL,
                emp_name Text NOT NULL,
                emp_age INT NOT NULL,
                emp_details JSON NULL,
                PRIMARY KEY (emp_id))'''
    cursor.execute(sql)
    print('Table created sucessully')
    connection.commit()
    connection.close()
    print("Table created")
    
except (Exception, Error) as error:
    print("Error while connecting to PostgreSQL", error)
finally:
    if (connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
